# %%
from sklearn.datasets import load_iris
from sklearn import tree
X, y = load_iris(return_X_y=True)
clf = tree.DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(X,y)

# %%
conda install graphviz
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\NBAndaru\Anaconda3
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.8.28  |                0         165 KB
#     certifi-2019.9.11          |           py37_0         155 KB
#     conda-4.8.0                |           py37_0         2.8 MB
#     openssl-1.1.1d             |       he774522_2         4.8 MB
#     ------------------------------------------------------------
#                                            Total:         8.0 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                  anaconda --> pkgs/main
#   certifi                                          anaconda --> pkgs/main
#   conda                                         conda-forge --> pkgs/main
#   openssl                                          anaconda --> pkgs/main
#
#
#
# Downloading and Extracting Packages
#
# certifi-2019.9.11    | 155 KB    |            |   0%
# certifi-2019.9.11    | 155 KB    | #          |  10%
# certifi-2019.9.11    | 155 KB    | ########## | 100%
#
# openssl-1.1.1d       | 4.8 MB    |            |   0%
# openssl-1.1.1d       | 4.8 MB    | #4         |  15%
# openssl-1.1.1d       | 4.8 MB    | ####5      |  45%
# openssl-1.1.1d       | 4.8 MB    | #######6   |  77%
# openssl-1.1.1d       | 4.8 MB    | ########## | 100%
#
# ca-certificates-2019 | 165 KB    |            |   0%
# ca-certificates-2019 | 165 KB    | ########## | 100%
#
# conda-4.8.0          | 2.8 MB    |            |   0%
# conda-4.8.0          | 2.8 MB    | ####3      |  44%
# conda-4.8.0          | 2.8 MB    | #######9   |  79%
# conda-4.8.0          | 2.8 MB    | ########## | 100%
#
# Note: you may need to restart the kernel to use updated packages.
# InvalidArchiveError('Error with archive C:\\Users\\NBAndaru\\Anaconda3\\pkgs\\openssl-1.1.1d-he774522_2oqu80xew\\pkg-openssl-1.1.1d-he774522_2.tar.zst.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nCould not unlink')

# %%
#blessup

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None)

# %%
conda install -c anaconda pydot
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\NBAndaru\Anaconda3
#
#   added / updated specs:
#     - pydot
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.8.28  |                0         165 KB  anaconda
#     certifi-2019.9.11          |           py37_0         155 KB  anaconda
#     conda-4.8.0                |           py37_0         3.0 MB  anaconda
#     openssl-1.1.1d             |       he774522_2         5.7 MB  anaconda
#     pydot-1.4.1                |           py37_0          43 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         9.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pydot              anaconda/win-64::pydot-1.4.1-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   certifi                                         pkgs/main --> anaconda
#   conda                                           pkgs/main --> anaconda
#   openssl                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# certifi-2019.9.11    | 155 KB    |            |   0%
# certifi-2019.9.11    | 155 KB    | #          |  10%
# certifi-2019.9.11    | 155 KB    | ########## | 100%
#
# pydot-1.4.1          | 43 KB     |            |   0%
# pydot-1.4.1          | 43 KB     | ###6       |  37%
# pydot-1.4.1          | 43 KB     | ########## | 100%
#
# ca-certificates-2019 | 165 KB    |            |   0%
# ca-certificates-2019 | 165 KB    | ########## | 100%
#
# openssl-1.1.1d       | 5.7 MB    |            |   0%
# openssl-1.1.1d       | 5.7 MB    | #8         |  19%
# openssl-1.1.1d       | 5.7 MB    | #####4     |  54%
# openssl-1.1.1d       | 5.7 MB    | ########4  |  84%
# openssl-1.1.1d       | 5.7 MB    | ########## | 100%
#
# conda-4.8.0          | 3.0 MB    |            |   0%
# conda-4.8.0          | 3.0 MB    | ##         |  20%
# conda-4.8.0          | 3.0 MB    | ########   |  81%
# conda-4.8.0          | 3.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge python-graphviz
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::certifi-2019.9.11-py37_0, anaconda::openssl-1.1.1d-he774522_2
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::openssl-1.1.1d-he774522_2, defaults::certifi-2019.9.11-py37_0
#   - anaconda::certifi-2019.9.11-py37_0, anaconda::openssl-1.1.1d-he774522_2, defaults::ca-certificates-2019.8.28-0
#   - anaconda::openssl-1.1.1d-he774522_2, defaults::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0
#   - anaconda::certifi-2019.9.11-py37_0, defaults::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-he774522_2
#   - defaults::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2done
#
# ## Package Plan ##
#
#   environment location: C:\Users\NBAndaru\Anaconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.0                |           py37_0         3.0 MB  conda-forge
#     python-graphviz-0.13.2     |             py_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   python-graphviz    conda-forge/noarch::python-graphviz-0.13.2-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda                                            anaconda --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# conda-4.8.0          | 3.0 MB    |            |   0%
# conda-4.8.0          | 3.0 MB    |            |   1%
# conda-4.8.0          | 3.0 MB    | ###3       |  34%
# conda-4.8.0          | 3.0 MB    | #######    |  71%
# conda-4.8.0          | 3.0 MB    | ########## | 100%
#
# python-graphviz-0.13 | 18 KB     |            |   0%
# python-graphviz-0.13 | 18 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge/label/broken python-graphviz
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::certifi-2019.9.11-py37_0, anaconda::openssl-1.1.1d-he774522_2
#   - anaconda::certifi-2019.9.11-py37_0, anaconda::openssl-1.1.1d-he774522_2, defaults::ca-certificates-2019.8.28-0
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::openssl-1.1.1d-he774522_2, defaults::certifi-2019.9.11-py37_0
#   - anaconda::openssl-1.1.1d-he774522_2, defaults::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0
#   - anaconda::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - defaults::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::certifi-2019.9.11-py37_0, defaults::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-he774522_2done
#
# ## Package Plan ##
#
#   environment location: C:\Users\NBAndaru\Anaconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python-graphviz-0.11       |             py_0          17 KB  conda-forge/label/broken
#     ------------------------------------------------------------
#                                            Total:          17 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   python-graphviz    conda-forge::python-graphviz-0.13.2-p~ --> conda-forge/label/broken::python-graphviz-0.11-py_0
#
#
#
# Downloading and Extracting Packages
#
# python-graphviz-0.11 | 17 KB     |            |   0%
# python-graphviz-0.11 | 17 KB     | #########2 |  92%
# python-graphviz-0.11 | 17 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING conda.models.version:get_matcher(531): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.*, but conda is ignoring the .* and treating it as 1

# %%
conda install -c conda-forge/label/cf201901 python-graphviz
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::certifi-2019.9.11-py37_0, anaconda::openssl-1.1.1d-he774522_2
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::openssl-1.1.1d-he774522_2, defaults::certifi-2019.9.11-py37_0
#   - anaconda::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::openssl-1.1.1d-he774522_2, defaults::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0
#   - defaults::ca-certificates-2019.8.28-0, defaults::certifi-2019.9.11-py37_0, defaults::openssl-1.1.1d-he774522_2
#   - anaconda::certifi-2019.9.11-py37_0, anaconda::openssl-1.1.1d-he774522_2, defaults::ca-certificates-2019.8.28-0
#   - anaconda::certifi-2019.9.11-py37_0, defaults::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-he774522_2done
#
# ## Package Plan ##
#
#   environment location: C:\Users\NBAndaru\Anaconda3
#
#   added / updated specs:
#     - python-graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python-graphviz-0.8.4      |        py37_1002          27 KB  conda-forge/label/cf201901
#     ------------------------------------------------------------
#                                            Total:          27 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   python-graphviz    conda-forge/label/broken/noarch::pyth~ --> conda-forge/label/cf201901/win-64::python-graphviz-0.8.4-py37_1002
#
#
#
# Downloading and Extracting Packages
#
# python-graphviz-0.8. | 27 KB     |            |   0%
# python-graphviz-0.8. | 27 KB     | #####9     |  60%
# python-graphviz-0.8. | 27 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
graph = graphviz.Source(dot_data)

# %%
graph.render('iris')
# Out:
# 'iris.pdf'

# %%
graph

# %%
tree.plot_tree(clf)
# Out:
# [Text(248.0, 338.79999999999995, 'X[3] <= 0.8\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(209.84615384615384, 277.2, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(286.15384615384613, 277.2, 'X[3] <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(152.6153846153846, 215.59999999999997, 'X[2] <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(76.3076923076923, 154.0, 'X[3] <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(38.15384615384615, 92.39999999999998, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(114.46153846153845, 92.39999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(228.9230769230769, 154.0, 'X[3] <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(190.76923076923077, 92.39999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(267.0769230769231, 92.39999999999998, 'X[0] <= 6.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(228.9230769230769, 30.80000000000001, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(305.2307692307692, 30.80000000000001, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(419.6923076923077, 215.59999999999997, 'X[2] <= 4.85\nentropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(381.53846153846155, 154.0, 'X[0] <= 5.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(343.38461538461536, 92.39999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(419.6923076923077, 92.39999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(457.8461538461538, 154.0, 'entropy = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]
