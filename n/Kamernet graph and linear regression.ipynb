# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

dataset = pd.read_json('C:/Users/mailv/Downloads/New folder/machine_learning/kamernet.json')
x = dataset[["area"]]
y = dataset['rent']

#train_test_split(x,y,test_size=0.3,random_state=0)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

regressor = LinearRegression()
regressor.fit(x_train,y_train)

coeff_df = pd.DataFrame(regressor.coef_, x.columns, columns=['Coefficient'])

y_prediction = regressor.predict(x_test)
df = pd.DataFrame({'Actual':y_test,'Predicted':y_prediction})

average_scores = 0
trialNum = 500
for i in range(trialNum):
  regressor = LinearRegression()
  x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)
  regressor.fit(x_train,y_train)
  score = regressor.score(x_test,y_test)
  average_scores += score
  #print(i,score)
average_scores = average_scores / trialNum
print("average_score", average_scores)
#plt.plot(x,y,"bo")
#plt.plot(x_test,y_prediction)
#plt.show()
# Out:
# average_score 0.706561540767693

# %%
plt.plot(x,y,"bo")
#plt.plot(x_test,y_prediction)
abc=plt.show()

# %%
from sklearn.linear_model import LinearRegression
abc.LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1936b3265afd> in <module>
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 abc.LinearRegression()
#
# AttributeError: 'NoneType' object has no attribute 'LinearRegression'

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

# %%
print(model)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plt.scatter(x,y)

# %%
LinearRegression(x,y)
# Out:
# LinearRegression(copy_X=True,
#          fit_intercept=     area
# 0      60
# 1      65
# 2       8
# 3      16
# 4      20
# 5      33
# 6      16
# 7       9
# 8      25
# 9      17
# 10     40
# 11     16
# 12     15
# 13     75
# 14     40
# 15     32
# 16     90
# 17      9
# 18     17
# 19     18
# 20     15
# 21     16
# 22     90
# 23     25
# 24     24
# 25     14
# 26     26
# 27    ...    15
# 259    12
# 260    14
# 261    30
# 262    71
# 263    20
# 264    60
# 265    14
#
# [266 rows x 1 columns],
#          n_jobs=None,
#          normalize=0       995
# 1       945
# 2       300
# 3       450
# 4       375
# 5       475
# 6       335
# 7       385
# 8       440
# 9       350
# 10      800
# 11      364
# 12      453
# 13     1150
# 14      950
# 15      801
# 16     1195
# 17      285
# 18      280
# 19      395
# 20      357
# 21      375
# 22     1100
# 23      335
# 24...20
# 261     470
# 262    1100
# 263     420
# 264    1200
# 265     360
# ...

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

dataset = pd.read_json('C:/Users/mailv/Downloads/New folder/machine_learning/kamernet.json')
x = dataset[["area"]]
y = dataset['rent']

#train_test_split(x,y,test_size=0.3,random_state=0)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

regressor = LinearRegression(fit_intercept=True)
regressor.fit(x_train,y_train)

coeff_df = pd.DataFrame(regressor.coef_, x.columns, columns=['Coefficient'])

y_prediction = regressor.predict(x_test)
df = pd.DataFrame({'Actual':y_test,'Predicted':y_prediction})

# %%
intercept_df = pd.DataFrame(regressor.intercept_, x.columns, columns=['Intercept'])
coeff_df = pd.DataFrame(regressor.coef_, x.columns, columns=['Coefficient'])
print(coeff_df)
print(intercept_df)
# Out:
#       Coefficient
# area    11.101385
#        Intercept
# area  238.938659

# %%
plt.scatter(x,y)

# %%
x2 = [0,100]
y2 = [238.938659,1349.077159]
plt.scatter(x,y)
plt.plot(x2,y2)
plt.show()

# %%
plt.plot(x_test, y_prediction)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b06a31e19cc3> in <module>
# ----> 1 plt.plot(x_test, y_prediction)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.plot(x_test, y_prediction)
plt.show()

# %%
plt.plot(x_test, y_prediction)
plt.show()

# %%
plt.plot(x_test, y_prediction)
plt.scatter(x_test,y_test)
plt.show()

# %%
fig = plt.figure()
fig.subplots_adjust(top=0.8)
ax1 = fig.add_subplot(211)
ax1.set_ylabel('Rent')
ax1.set_title('Area')
# Out:
# Text(0.5, 1.0, 'Area')

# %%
plt.plot(x_test, y_prediction)
plt.scatter(x_test,y_test)
plt.xlabel("Area / m^2")
plt.ylabel("Rent / €")
plt.show()

# %%
plt.scatter(x,y)
plt.xlabel("Area / m^2")
plt.ylabel("Rent / €")
plt.show()
