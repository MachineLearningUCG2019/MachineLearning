# %%
# load the iris dataset 
from sklearn.datasets import load_iris 
iris = load_iris() 
# store the feature matrix (X) and response vector (y) 
X = iris.data 
y = iris.target 
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1) 
# training the model on training set 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train, y_train) 
# making predictions on the testing set 
y_pred = gnb.predict(X_test) 
# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 95.0

# %%
import math

# %%
z = [-2,-1,0,1,2]

# %%
def phi(z):
    return 1 / (1 + math.exp(-z))

# %%
y = []
for i in z:
    y.append(phi(i))

import matplotlib.pyplot as plt

plt.scatter(z,y)

# %%
import numpy as np


def phi(z):
    return 1 / (1 + math.exp(-z))

z = np.linspace(-2,2,100)
y = 1 / (1 + np.exp(-z))

plt.plot(z,y)

# %%
import numpy as np

a = 2
b = 0

z = np.linspace(-10,10,10000)
y = 1 / (1 + np.exp(-a*z+b))

plt.plot(z,y)

# %%
import numpy as np

a = 2
b = 10

z = np.linspace(-10,10,10000)
y = 1 / (1 + np.exp(-a*z+b))

plt.plot(z,y)

# %%
def F(y,x,a,b):
    cost = np.sum((y - (a*x + b))**2)
    return (y - a*x + b)**2

def Fd(y,x,a,b):
    return [-x*2*(y-a*x+b),2*(y-a*x+b)]



rng = np.random.RandomState(42)
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
plt.scatter(x,y)

# %%
def F(y,x,a,b):
    cost = np.sum((y - (a*x + b))**2)
    return cost

def Fd(y,x,a,b):
    return np.sum((-x)*2*(y-(a*x+b))),np.sum((-1)*2*(y-(a*x+b)))



Fd(y,x,2.,-1.)
# Out:
# (19.586796046322625, 0.2945285466902394)

# %%
'''rng = np.random.RandomState(42)
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
#plt.scatter(x,y)

a = 2
b = -1

step = 0.01
print(F(y,x,a,b))
for i in range(1000):
    da, db = Fd(y,x,a,b)
    a = a - da * step
    b = b - db * step

print(a)
print(b)
print(F(y,x,a,b))'''
# Out:
# 'rng = np.random.RandomState(42)\nx = 10 * rng.rand(50)\ny = 2 * x - 1 + rng.randn(50)\n#plt.scatter(x,y)\n\na = 2\nb = -1\n\nstep = 0.01\nprint(F(y,x,a,b))\nfor i in range(1000):\n    da, db = Fd(y,x,a,b)\n    a = a - da * step\n    b = b - db * step\n\nprint(a)\nprint(b)\nprint(F(y,x,a,b))'

# %%
def GB(a,b):
    return a,b
